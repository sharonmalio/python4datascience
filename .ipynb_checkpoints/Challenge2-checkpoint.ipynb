# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# Blood donations Dataset
test_data= pd.read_csv('BloodDonationPredictions/TestDataBlood.csv')
training_data = pd.read_csv('BloodDonationPredictions/TrainingDataBlood.csv')
table1= pd.DataFrame(test_data)
table2= pd.DataFrame(training_data)

# %%
table1.head(10)
# Out:
#    Donor Id  Months since Last Donation  Number of Donations  \
# 0       659                           2                   12
# 1       276                          21                    7
# 2       263                           4                    1
# 3       303                          11                   11
# 4        83                           4                   12
# 5       500                           3                   21
# 6       530                           4                    2
# 7       244                          14                    1
# 8       249                          23                    2
# 9       728                          14                    4
#
#    Total Volume Donated (c.c.)  Months since First Donation
# 0                         3000                           52
# 1                         1750                           38
# 2                          250                            4
# 3                         2750                           38
# 4                         3000                           34
# 5                         5250                           42
# 6                          500                            4
# 7                          250                           14
# 8                          500                           87
# 9                         1000                           64

# %%
table2.head(10)
# Out:
#    Donor Id  Months since Last Donation  Number of Donations  \
# 0       619                           2                   50
# 1       664                           0                   13
# 2       441                           1                   16
# 3       160                           2                   20
# 4       358                           1                   24
# 5       335                           4                    4
# 6        47                           2                    7
# 7       164                           1                   12
# 8       736                           5                   46
# 9       436                           0                    3
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
# 5                         1000                            4
# 6                         1750                           14
# 7                         3000                           35
# 8                        11500                           98
# 9                          750                            4
#
#    Made Donation in March 2007
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            0
# 5                            0
# 6                            1
# 7                            0
# 8                            1
# 9                            0

# %%
print('Test Data columns with null values:\n', table1.isnull().sum())
print("-"*10)
print('Train Data columns with null values:\n', table2.isnull().sum())
print("-"*10)
# Out:
# Test Data columns with null values:
#  Donor Id                       0
# Months since Last Donation     0
# Number of Donations            0
# Total Volume Donated (c.c.)    0
# Months since First Donation    0
# dtype: int64
# ----------
# Train Data columns with null values:
#  Donor Id                       0
# Months since Last Donation     0
# Number of Donations            0
# Total Volume Donated (c.c.)    0
# Months since First Donation    0
# Made Donation in March 2007    0
# dtype: int64
# ----------

# %%
table2.describe()
# Out:
#          Donor Id  Months since Last Donation  Number of Donations  \
# count  576.000000                  576.000000           576.000000
# mean   374.034722                    9.439236             5.427083
# std    216.947773                    8.175454             5.740010
# min      0.000000                    0.000000             1.000000
# 25%    183.750000                    2.000000             2.000000
# 50%    375.500000                    7.000000             4.000000
# 75%    562.500000                   14.000000             7.000000
# max    747.000000                   74.000000            50.000000
#
#        Total Volume Donated (c.c.)  Months since First Donation  \
# count                   576.000000                   576.000000
# mean                   1356.770833                    34.050347
# std                    1435.002556                    24.227672
# min                     250.000000                     2.000000
# 25%                     500.000000                    16.000000
# 50%                    1000.000000                    28.000000
# 75%                    1750.000000                    49.250000
# max                   12500.000000                    98.000000
#
#        Made Donation in March 2007
# count                   576.000000
# mean                      0.239583
# std                       0.427200
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000

# %%
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 6 columns):
# Donor Id                       576 non-null int64
# Months since Last Donation     576 non-null int64
# Number of Donations            576 non-null int64
# Total Volume Donated (c.c.)    576 non-null int64
# Months since First Donation    576 non-null int64
# Made Donation in March 2007    576 non-null int64
# dtypes: int64(6)
# memory usage: 27.1 KB

# %%
# merge the data between the 2 tables
table1['Made Donation in March 2007'] = 'NaN'
data = table2.append(table1)
data.head(10)

# feature engineering
# Out:
#    Donor Id  Months since Last Donation  Number of Donations  \
# 0       619                           2                   50
# 1       664                           0                   13
# 2       441                           1                   16
# 3       160                           2                   20
# 4       358                           1                   24
# 5       335                           4                    4
# 6        47                           2                    7
# 7       164                           1                   12
# 8       736                           5                   46
# 9       436                           0                    3
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
# 5                         1000                            4
# 6                         1750                           14
# 7                         3000                           35
# 8                        11500                           98
# 9                          750                            4
#
#   Made Donation in March 2007
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           0
# 5                           0
# 6                           1
# 7                           0
# 8                           1
# 9                           0

# %%
#I have renamed the "Unnamed: 0" to Donor ID and thus, 
# for now we assume that it has no connection with the donation
# lets drop it for now 
data.drop("Donor Id",axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-2289b75aab7b> in <module>
#       2 # for now we assume that it has no connection with the donation
#       3 # lets drop it for now
# ----> 4 data.drop("Donor Id",axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['Donor Id'] not found in axis"

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 0 to 199
# Data columns (total 5 columns):
# Months since Last Donation     776 non-null int64
# Number of Donations            776 non-null int64
# Total Volume Donated (c.c.)    776 non-null int64
# Months since First Donation    776 non-null int64
# Made Donation in March 2007    776 non-null object
# dtypes: int64(4), object(1)
# memory usage: 56.4+ KB
#    Months since Last Donation  Number of Donations  \
# 0                           2                   50
# 1                           0                   13
# 2                           1                   16
# 3                           2                   20
# 4                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#   Made Donation in March 2007
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           0

# %%
# calculating months that the user has been donating
data['Months Donating'] = data['Months since First Donation'] - data['Months since Last Donation']
# calculating donations per month for the user
data['Donations per Months Donating'] = data["""Total Volume Donated (c.c.)"""]/data['Months Donating']
data['Donations per Months Donating'] = data['Donations per Months Donating'].replace(np.inf, 999)
# calculating donations per month since the first donation for the user
data['Donations per Months since First Donation'] = data["""Total Volume Donated (c.c.)"""]/data['Months since First Donation']

data['Donation Counts per Months Donating'] = data['Number of Donations']/data['Months Donating']
data['Donation Counts per Months Donating'] = data['Donation Counts per Months Donating'].replace(np.inf, 999)
data['Donation Counts per Months since First Donating'] = data['Number of Donations']/data['Months since First Donation']
data['Donation Counts per Months since First Donating'] = data['Donation Counts per Months since First Donating'].replace(np.inf, 999)
# 
data['Donation Volume per Donation'] = (data["""Total Volume Donated (c.c.)"""]/data['Number of Donations']).replace(np.inf, 999)

# %%
test = data[data['Made Donation in March 2007'] == 'NaN']
test.head(5)
# Out:
#    Months since Last Donation  Number of Donations  \
# 0                           2                   12
# 1                          21                    7
# 2                           4                    1
# 3                          11                   11
# 4                           4                   12
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                         3000                           52
# 1                         1750                           38
# 2                          250                            4
# 3                         2750                           38
# 4                         3000                           34
#
#   Made Donation in March 2007  Months Donating  Donations per Months Donating  \
# 0                         NaN               50                      60.000000
# 1                         NaN               17                     102.941176
# 2                         NaN                0                     999.000000
# 3                         NaN               27                     101.851852
# 4                         NaN               30                     100.000000
#
#    Donations per Months since First Donation  \
# 0                                  57.692308
# 1                                  46.052632
# 2                                  62.500000
# 3                                  72.368421
# 4                                  88.235294
#
#    Donation Counts per Months Donating  \
# 0                             0.240000
# 1                             0.411765
# 2                           999.000000
# 3                             0.407407
# 4                             0.400000
#
#    Donation Counts per Months since First Donating  \
# 0                                         0.230769
# 1                                         0.184211
# 2                                         0.250000
# 3                                         0.289474
# 4                                         0.352941
#
#    Donation Volume per Donation
# 0                         250.0
# 1                         250.0
# 2                         250.0
# 3                         250.0
# 4                         250.0

# %%
test.drop(["Made Donation in March 2007"], axis = 1)
train = data[data['Made Donation in March 2007'] != 'NaN']
train.head(5)
# Out:
#    Months since Last Donation  Number of Donations  \
# 0                           2                   50
# 1                           0                   13
# 2                           1                   16
# 3                           2                   20
# 4                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#   Made Donation in March 2007  Months Donating  Donations per Months Donating  \
# 0                           1               96                     130.208333
# 1                           1               28                     116.071429
# 2                           1               34                     117.647059
# 3                           1               43                     116.279070
# 4                           0               76                      78.947368
#
#    Donations per Months since First Donation  \
# 0                                 127.551020
# 1                                 116.071429
# 2                                 114.285714
# 3                                 111.111111
# 4                                  77.922078
#
#    Donation Counts per Months Donating  \
# 0                             0.520833
# 1                             0.464286
# 2                             0.470588
# 3                             0.465116
# 4                             0.315789
#
#    Donation Counts per Months since First Donating  \
# 0                                         0.510204
# 1                                         0.464286
# 2                                         0.457143
# 3                                         0.444444
# 4                                         0.311688
#
#    Donation Volume per Donation
# 0                         250.0
# 1                         250.0
# 2                         250.0
# 3                         250.0
# 4                         250.0

# %%
final_train = train.drop(['Made Donation in March 2007'], axis = 1)
final_train.head(10)
# Out:
#    Months since Last Donation  Number of Donations  \
# 0                           2                   50
# 1                           0                   13
# 2                           1                   16
# 3                           2                   20
# 4                           1                   24
# 5                           4                    4
# 6                           2                    7
# 7                           1                   12
# 8                           5                   46
# 9                           0                    3
#
#    Total Volume Donated (c.c.)  Months since First Donation  Months Donating  \
# 0                        12500                           98               96
# 1                         3250                           28               28
# 2                         4000                           35               34
# 3                         5000                           45               43
# 4                         6000                           77               76
# 5                         1000                            4                0
# 6                         1750                           14               12
# 7                         3000                           35               34
# 8                        11500                           98               93
# 9                          750                            4                4
#
#    Donations per Months Donating  Donations per Months since First Donation  \
# 0                     130.208333                                 127.551020
# 1                     116.071429                                 116.071429
# 2                     117.647059                                 114.285714
# 3                     116.279070                                 111.111111
# 4                      78.947368                                  77.922078
# 5                     999.000000                                 250.000000
# 6                     145.833333                                 125.000000
# 7                      88.235294                                  85.714286
# 8                     123.655914                                 117.346939
# 9                     187.500000                                 187.500000
#
#    Donation Counts per Months Donating  \
# 0                             0.520833
# 1                             0.464286
# 2                             0.470588
# 3                             0.465116
# 4                             0.315789
# 5                           999.000000
# 6                             0.583333
# 7                             0.352941
# 8                             0.494624
# 9                             0.750000
#
#    Donation Counts per Months since First Donating  \
# 0                                         0.510204
# 1                                         0.464286
# 2                                         0.457143
# 3                                         0.444444
# 4                                         0.311688
# 5                                         1.000000
# 6                                         0.500000
# 7                                         0.342857
# 8                                         0.469388
# 9                                         0.750000
#
#    Donation Volume per Donation
# 0                         250.0
# 1                         250.0
# 2                         250.0
# 3                         250.0
# 4                         250.0
# 5                         250.0
# 6                         250.0
# 7                         250.0
# 8                         250.0
# 9                         250.0

# %%
from sklearn.model_selection import train_test_split

# %%
volume_donated = pd.DataFrame(data['Number of Donations'])
volume_donated.reset_index(inplace=True)
volume_donated.columns = ['Number of Donations', 'Total Volume Donated (c.c.)']

plt.figure(figsize=(20, 7))

barplot = sns.barplot(x=volume_donated['Number of Donations'], y=volume_donated['Total Volume Donated (c.c.)'])
barplot.set(xlabel='Number of Donations', ylabel='Total Volume Donated')
plt.title('Top 20 donations:', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
